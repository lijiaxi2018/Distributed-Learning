# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# Plot
plot_directory = 'result/plot_set'

# %%
# colors = [
#     '#e6194B',
#     '#f58231',
#     '#9A6324',
#     '#911eb4',
#     '#3cb44b',
#     '#f032e6',
#     '#4363d8',
# ]

# %%
colors = [
	'#FF0000',
	'#00FFFF',
	'#0000FF',
	'#00008B',
	'#ADD8E6',
	'#800080',
	'#7FFFD4',
	'#008000',
	'#FF00FF',
	'#FFC0CB',
	'#C0C0C0',
	'#FFA500',
	'#000000',
	'#800000',
]

# %%
def load_json_file(file_path):
	try:
		with open(file_path, 'r') as file:
			data = json.load(file)
		return data
	
	except Exception as e:
		print(f"An error occurred while loading the JSON file: {e}")
		return None

# %%
def extract_fpss(metric_list):
	return list(metric_list[list(metric_list.keys())[0]][0]['metric'].keys())

# %%
def to_accuracy_vector(accuracy_result_seq, fpss, type='F1'):
	accuracy_vector = []
	for fps in fpss:
		accuracy_vector.append(accuracy_result_seq[fps][type])
	
	return accuracy_vector

# %%
def plot_scatter(xs, ys, x_label, y_label, title, fig_size=(8, 8)):
	plt.figure(figsize=fig_size)
	plt.scatter(xs, ys, c=colors[0], s=30, alpha=0.5)
	plt.title(title)
	plt.xlabel(x_label)
	plt.ylabel(y_label)
	plt.show()

# %%
def plot_scatter_label(xs, ys, labels, x_label, y_label, title, fig_size=(8, 8)):
	plt.figure(figsize=fig_size)
	for i in range(len(xs)):
		plt.scatter(xs[i], ys[i], c=colors[labels[i]], s=30, alpha=0.5)
	plt.title(title)
	plt.xlabel(x_label)
	plt.ylabel(y_label)
	plt.show()

# %%
def filter_list_index(input_list, indices_to_remove):
	return [item for i, item in enumerate(input_list) if i not in indices_to_remove]

# %%
def round_float_to_sigfigs(number, sigfigs):
	return round(number, sigfigs)

# %% [markdown]
# ## Plot

# %%
omv_features = ["Left-Top", "Right-Top", "Left-Bottom", "Right-Bottom", "Object-Amount", "Confidence", "IOU"]

# %%
plot_filenames = sorted(os.listdir(plot_directory))
plot_video_names = sorted(list(set([f.split('_')[0] for f in plot_filenames])))

# %%
fpss = extract_fpss(load_json_file(os.path.join(plot_directory, plot_video_names[0] + "_Accuracy_Result.json")))

# %%
omv_videos = []
acc_videos = []

for v in plot_video_names:
	omv_dict = {}
	for fps in fpss:
		omv_dict[fps] = []
	acc_list = []

	accuracy_result = load_json_file(os.path.join(plot_directory, v + "_Accuracy_Result.json"))
	movement_result = load_json_file(os.path.join(plot_directory, v + "_Movement_Result.json"))

	for class_idx in list(accuracy_result.keys()):
		for i in range(len(accuracy_result[class_idx])):
			accuracy_vector = to_accuracy_vector(accuracy_result[class_idx][i]['metric'], fpss)
			acc_list.append(accuracy_vector)

			for fps in fpss:
				movement_vector = movement_result[class_idx][i]['movement'][fps]
				omv_dict[fps].append(movement_vector)
	
	omv_videos.append(omv_dict)
	acc_videos.append(acc_list)

# %%
# Corr Plot Format 1

for i in range(len(plot_video_names)):
	video_name = plot_video_names[i]
	for j in range(len(omv_videos[0][fpss[0]][0])):
		for k in range(len(fpss)):
			fps = fpss[k]
			
			omv_fps = list(np.array(omv_videos[i][fps])[:, j])
			acc_fps = list(np.array(acc_videos[i])[:, k])

			# Remove Outliers
			outlier_index = [l for l in range(len(omv_fps)) if omv_fps[l] == -1]
			omv_fps_clean = filter_list_index(omv_fps, outlier_index)
			acc_fps_clean = filter_list_index(acc_fps, outlier_index)

			title = f'{video_name}; OMV Feature {j} ({omv_features[j]}); FPS: {fps}'

			correlation_matrix = np.corrcoef(omv_fps_clean, acc_fps_clean)
			correlation_coefficient = correlation_matrix[0, 1]
			print(f"{title} -> Corr: {round_float_to_sigfigs(correlation_coefficient, 3)}")
			# plot_scatter(omv_fps_clean, acc_fps_clean, 'OMV Feature', 'ACC', title)

		print("")
# Out:
# Video1; OMV Feature 0 (Left-Top); FPS: 1 -> Corr: -0.026
# Video1; OMV Feature 0 (Left-Top); FPS: 2 -> Corr: -0.028
# Video1; OMV Feature 0 (Left-Top); FPS: 3 -> Corr: 0.009
# Video1; OMV Feature 0 (Left-Top); FPS: 5 -> Corr: 0.153
# Video1; OMV Feature 0 (Left-Top); FPS: 6 -> Corr: 0.234
# Video1; OMV Feature 0 (Left-Top); FPS: 10 -> Corr: 0.244
# Video1; OMV Feature 0 (Left-Top); FPS: 15 -> Corr: 0.249
# Video1; OMV Feature 0 (Left-Top); FPS: 30 -> Corr: 0.249
#
# Video1; OMV Feature 1 (Right-Top); FPS: 1 -> Corr: 0.012
# Video1; OMV Feature 1 (Right-Top); FPS: 2 -> Corr: -0.002
# Video1; OMV Feature 1 (Right-Top); FPS: 3 -> Corr: 0.039
# Video1; OMV Feature 1 (Right-Top); FPS: 5 -> Corr: 0.202
# Video1; OMV Feature 1 (Right-Top); FPS: 6 -> Corr: 0.302
# Video1; OMV Feature 1 (Right-Top); FPS: 10 -> Corr: 0.298
# Video1; OMV Feature 1 (Right-Top); FPS: 15 -> Corr: 0.312
# Video1; OMV Feature 1 (Right-Top); FPS: 30 -> Corr: 0.319
#
# Video1; OMV Feature 2 (Left-Bottom); FPS: 1 -> Corr: -0.019
# Video1; OMV Feature 2 (Left-Bottom); FPS: 2 -> Corr: -0.034
# Video1; OMV Feature 2 (Left-Bottom); FPS: 3 -> Corr: 0.015
# Video1; OMV Feature 2 (Left-Bottom); FPS: 5 -> Corr: 0.165
# Video1; OMV Feature 2 (Left-Bottom); FPS: 6 -> Corr: 0.249
# Video1; OMV Feature 2 (Left-Bottom); FPS: 10 -> Corr: 0.258
# Video1; OMV Feature 2 (Left-Bottom); FPS: 15 -> Corr: 0.263
# Video1; OMV Feature 2 (Left-Bottom); FPS: 30 -> Corr: 0.266
#
# Video1; OMV Feature 3 (Right-Bottom); FPS: 1 -> Corr: 0.017
# Video1; OMV Feature 3 (Right-Bottom); FPS: 2 -> Corr: -0.003
# Video1; OMV Feature 3 (Right-Bottom); FPS: 3 -> Corr: 0.043
# Video1; OMV Feature 3 (Right-Bottom); FPS: 5 -> Corr: 0.21
# Video1; OMV Feature 3 (Right-Bottom); FPS: 6 -> Corr: 0.31
# Video1; OMV Feature 3 (Right-Bottom); FPS: 10 -> Corr: 0.307
# Video1; OMV Feature 3 (Right-Bottom); FPS: 15 -> Corr: 0.321
# Video1; OMV Feature 3 (Right-Bottom); FPS: 30 -> Corr: 0.33
#
# Video1; OMV Feature 4 (Object-Amount); FPS: 1 -> Corr: 0.359
# Video1; OMV Feature 4 (Object-Amount); FPS: 2 -> Corr: 0.343
# Video1; OMV Feature 4 (Object-Amount); FPS: 3 -> Corr: 0.243
# Video1; OMV Feature 4 (Object-Amount); FPS: 5 -> Corr: -0.086
# Video1; OMV Feature 4 (Object-Amount); FPS: 6 -> Corr: -0.204
# Video1; OMV Feature 4 (Object-Amount); FPS: 10 -> Corr: -0.334
# Video1; OMV Feature 4 (Object-Amount); FPS: 15 -> Corr: -0.35
# Video1; OMV Feature 4 (Object-Amount); FPS: 30 -> Corr: -0.352
#
# Video1; OMV Feature 5 (Confidence); FPS: 1 -> Corr: 0.311
# Video1; OMV Feature 5 (Confidence); FPS: 2 -> Corr: 0.368
# Video1; OMV Feature 5 (Confidence); FPS: 3 -> Corr: 0.436
# Video1; OMV Feature 5 (Confidence); FPS: 5 -> Corr: 0.55
# Video1; OMV Feature 5 (Confidence); FPS: 6 -> Corr: 0.621
# Video1; OMV Feature 5 (Confidence); FPS: 10 -> Corr: 0.65
# Video1; OMV Feature 5 (Confidence); FPS: 15 -> Corr: 0.653
# Video1; OMV Feature 5 (Confidence); FPS: 30 -> Corr: 0.664
#
# Video1; OMV Feature 6 (IOU); FPS: 1 -> Corr: 0.504
# Video1; OMV Feature 6 (IOU); FPS: 2 -> Corr: 0.488
# Video1; OMV Feature 6 (IOU); FPS: 3 -> Corr: 0.399
# Video1; OMV Feature 6 (IOU); FPS: 5 -> Corr: 0.46
# Video1; OMV Feature 6 (IOU); FPS: 6 -> Corr: 0.458
# Video1; OMV Feature 6 (IOU); FPS: 10 -> Corr: 0.381
# Video1; OMV Feature 6 (IOU); FPS: 15 -> Corr: 0.35
# Video1; OMV Feature 6 (IOU); FPS: 30 -> Corr: 0.343
#
# Video2; OMV Feature 0 (Left-Top); FPS: 1 -> Corr: 0.058
# Video2; OMV Feature 0 (Left-Top); FPS: 2 -> Corr: 0.168
# Video2; OMV Feature 0 (Left-Top); FPS: 3 -> Corr: 0.199
# Video2; OMV Feature 0 (Left-Top); FPS: 5 -> Corr: 0.294
# Video2; OMV Feature 0 (Left-Top); FPS: 6 -> Corr: 0.389
# Video2; OMV Feature 0 (Left-Top); FPS: 10 -> Corr: 0.304
# Video2; OMV Feature 0 (Left-Top); FPS: 15 -> Corr: 0.254
# Video2; OMV Feature 0 (Left-Top); FPS: 30 -> Corr: 0.269
#
# Video2; OMV Feature 1 (Right-Top); FPS: 1 -> Corr: 0.011
# Video2; OMV Feature 1 (Right-Top); FPS: 2 -> Corr: 0.133
# Video2; OMV Feature 1 (Right-Top); FPS: 3 -> Corr: 0.195
# Video2; OMV Feature 1 (Right-Top); FPS: 5 -> Corr: 0.297
# Video2; OMV Feature 1 (Right-Top); FPS: 6 -> Corr: 0.417
# Video2; OMV Feature 1 (Right-Top); FPS: 10 -> Corr: 0.321
# Video2; OMV Feature 1 (Right-Top); FPS: 15 -> Corr: 0.278
# Video2; OMV Feature 1 (Right-Top); FPS: 30 -> Corr: 0.276
#
# Video2; OMV Feature 2 (Left-Bottom); FPS: 1 -> Corr: 0.051
# Video2; OMV Feature 2 (Left-Bottom); FPS: 2 -> Corr: 0.149
# Video2; OMV Feature 2 (Left-Bottom); FPS: 3 -> Corr: 0.183
# Video2; OMV Feature 2 (Left-Bottom); FPS: 5 -> Corr: 0.291
# Video2; OMV Feature 2 (Left-Bottom); FPS: 6 -> Corr: 0.381
# Video2; OMV Feature 2 (Left-Bottom); FPS: 10 -> Corr: 0.311
# Video2; OMV Feature 2 (Left-Bottom); FPS: 15 -> Corr: 0.263
# Video2; OMV Feature 2 (Left-Bottom); FPS: 30 -> Corr: 0.278
#
# Video2; OMV Feature 3 (Right-Bottom); FPS: 1 -> Corr: 0.006
# Video2; OMV Feature 3 (Right-Bottom); FPS: 2 -> Corr: 0.122
# Video2; OMV Feature 3 (Right-Bottom); FPS: 3 -> Corr: 0.186
# Video2; OMV Feature 3 (Right-Bottom); FPS: 5 -> Corr: 0.299
# Video2; OMV Feature 3 (Right-Bottom); FPS: 6 -> Corr: 0.413
# Video2; OMV Feature 3 (Right-Bottom); FPS: 10 -> Corr: 0.333
# Video2; OMV Feature 3 (Right-Bottom); FPS: 15 -> Corr: 0.289
# Video2; OMV Feature 3 (Right-Bottom); FPS: 30 -> Corr: 0.29
#
# Video2; OMV Feature 4 (Object-Amount); FPS: 1 -> Corr: 0.476
# Video2; OMV Feature 4 (Object-Amount); FPS: 2 -> Corr: 0.537
# Video2; OMV Feature 4 (Object-Amount); FPS: 3 -> Corr: 0.598
# Video2; OMV Feature 4 (Object-Amount); FPS: 5 -> Corr: 0.448
# Video2; OMV Feature 4 (Object-Amount); FPS: 6 -> Corr: 0.459
# Video2; OMV Feature 4 (Object-Amount); FPS: 10 -> Corr: 0.264
# Video2; OMV Feature 4 (Object-Amount); FPS: 15 -> Corr: 0.17
# Video2; OMV Feature 4 (Object-Amount); FPS: 30 -> Corr: 0.125
#
# Video2; OMV Feature 5 (Confidence); FPS: 1 -> Corr: -0.193
# Video2; OMV Feature 5 (Confidence); FPS: 2 -> Corr: -0.137
# Video2; OMV Feature 5 (Confidence); FPS: 3 -> Corr: 0.002
# Video2; OMV Feature 5 (Confidence); FPS: 5 -> Corr: 0.103
# Video2; OMV Feature 5 (Confidence); FPS: 6 -> Corr: 0.155
# Video2; OMV Feature 5 (Confidence); FPS: 10 -> Corr: 0.292
# Video2; OMV Feature 5 (Confidence); FPS: 15 -> Corr: 0.355
# Video2; OMV Feature 5 (Confidence); FPS: 30 -> Corr: 0.401
#
# Video2; OMV Feature 6 (IOU); FPS: 1 -> Corr: 0.317
# Video2; OMV Feature 6 (IOU); FPS: 2 -> Corr: 0.257
# Video2; OMV Feature 6 (IOU); FPS: 3 -> Corr: 0.121
# Video2; OMV Feature 6 (IOU); FPS: 5 -> Corr: 0.15
# Video2; OMV Feature 6 (IOU); FPS: 6 -> Corr: 0.201
# Video2; OMV Feature 6 (IOU); FPS: 10 -> Corr: -0.02
# Video2; OMV Feature 6 (IOU); FPS: 15 -> Corr: -0.142
# Video2; OMV Feature 6 (IOU); FPS: 30 -> Corr: -0.206
#
# Video3; OMV Feature 0 (Left-Top); FPS: 1 -> Corr: -0.113
# Video3; OMV Feature 0 (Left-Top); FPS: 2 -> Corr: -0.03
# Video3; OMV Feature 0 (Left-Top); FPS: 3 -> Corr: -0.066
# Video3; OMV Feature 0 (Left-Top); FPS: 5 -> Corr: 0.052
# Video3; OMV Feature 0 (Left-Top); FPS: 6 -> Corr: -0.011
# Video3; OMV Feature 0 (Left-Top); FPS: 10 -> Corr: 0.036
# Video3; OMV Feature 0 (Left-Top); FPS: 15 -> Corr: -0.003
# Video3; OMV Feature 0 (Left-Top); FPS: 30 -> Corr: -0.016
#
# Video3; OMV Feature 1 (Right-Top); FPS: 1 -> Corr: -0.105
# Video3; OMV Feature 1 (Right-Top); FPS: 2 -> Corr: 0.008
# Video3; OMV Feature 1 (Right-Top); FPS: 3 -> Corr: -0.033
# Video3; OMV Feature 1 (Right-Top); FPS: 5 -> Corr: 0.102
# Video3; OMV Feature 1 (Right-Top); FPS: 6 -> Corr: 0.043
# Video3; OMV Feature 1 (Right-Top); FPS: 10 -> Corr: 0.097
# Video3; OMV Feature 1 (Right-Top); FPS: 15 -> Corr: 0.042
# Video3; OMV Feature 1 (Right-Top); FPS: 30 -> Corr: 0.006
#
# Video3; OMV Feature 2 (Left-Bottom); FPS: 1 -> Corr: -0.119
# Video3; OMV Feature 2 (Left-Bottom); FPS: 2 -> Corr: -0.032
# Video3; OMV Feature 2 (Left-Bottom); FPS: 3 -> Corr: -0.068
# Video3; OMV Feature 2 (Left-Bottom); FPS: 5 -> Corr: 0.051
# Video3; OMV Feature 2 (Left-Bottom); FPS: 6 -> Corr: -0.017
# Video3; OMV Feature 2 (Left-Bottom); FPS: 10 -> Corr: 0.031
# Video3; OMV Feature 2 (Left-Bottom); FPS: 15 -> Corr: -0.01
# Video3; OMV Feature 2 (Left-Bottom); FPS: 30 -> Corr: -0.017
#
# Video3; OMV Feature 3 (Right-Bottom); FPS: 1 -> Corr: -0.106
# Video3; OMV Feature 3 (Right-Bottom); FPS: 2 -> Corr: 0.003
# Video3; OMV Feature 3 (Right-Bottom); FPS: 3 -> Corr: -0.035
# Video3; OMV Feature 3 (Right-Bottom); FPS: 5 -> Corr: 0.101
# Video3; OMV Feature 3 (Right-Bottom); FPS: 6 -> Corr: 0.036
# Video3; OMV Feature 3 (Right-Bottom); FPS: 10 -> Corr: 0.091
# Video3; OMV Feature 3 (Right-Bottom); FPS: 15 -> Corr: 0.035
# Video3; OMV Feature 3 (Right-Bottom); FPS: 30 -> Corr: 0.008
#
# Video3; OMV Feature 4 (Object-Amount); FPS: 1 -> Corr: 0.568
# Video3; OMV Feature 4 (Object-Amount); FPS: 2 -> Corr: 0.603
# Video3; OMV Feature 4 (Object-Amount); FPS: 3 -> Corr: 0.605
# Video3; OMV Feature 4 (Object-Amount); FPS: 5 -> Corr: 0.576
# Video3; OMV Feature 4 (Object-Amount); FPS: 6 -> Corr: 0.499
# Video3; OMV Feature 4 (Object-Amount); FPS: 10 -> Corr: 0.437
# Video3; OMV Feature 4 (Object-Amount); FPS: 15 -> Corr: 0.332
# Video3; OMV Feature 4 (Object-Amount); FPS: 30 -> Corr: 0.245
#
# Video3; OMV Feature 5 (Confidence); FPS: 1 -> Corr: 0.044
# Video3; OMV Feature 5 (Confidence); FPS: 2 -> Corr: 0.024
# Video3; OMV Feature 5 (Confidence); FPS: 3 -> Corr: 0.132
# Video3; OMV Feature 5 (Confidence); FPS: 5 -> Corr: 0.142
# Video3; OMV Feature 5 (Confidence); FPS: 6 -> Corr: 0.185
# Video3; OMV Feature 5 (Confidence); FPS: 10 -> Corr: 0.199
# Video3; OMV Feature 5 (Confidence); FPS: 15 -> Corr: 0.221
# Video3; OMV Feature 5 (Confidence); FPS: 30 -> Corr: 0.271
#
# Video3; OMV Feature 6 (IOU); FPS: 1 -> Corr: 0.462
# Video3; OMV Feature 6 (IOU); FPS: 2 -> Corr: 0.434
# Video3; OMV Feature 6 (IOU); FPS: 3 -> Corr: 0.312
# Video3; OMV Feature 6 (IOU); FPS: 5 -> Corr: 0.37
# Video3; OMV Feature 6 (IOU); FPS: 6 -> Corr: 0.357
# Video3; OMV Feature 6 (IOU); FPS: 10 -> Corr: 0.32
# Video3; OMV Feature 6 (IOU); FPS: 15 -> Corr: 0.268
# Video3; OMV Feature 6 (IOU); FPS: 30 -> Corr: 0.177
#
# Video4; OMV Feature 0 (Left-Top); FPS: 1 -> Corr: -0.168
# Video4; OMV Feature 0 (Left-Top); FPS: 2 -> Corr: -0.204
# Video4; OMV Feature 0 (Left-Top); FPS: 3 -> Corr: -0.369
# Video4; OMV Feature 0 (Left-Top); FPS: 5 -> Corr: -0.335
# Video4; OMV Feature 0 (Left-Top); FPS: 6 -> Corr: -0.307
# Video4; OMV Feature 0 (Left-Top); FPS: 10 -> Corr: -0.254
# Video4; OMV Feature 0 (Left-Top); FPS: 15 -> Corr: -0.264
# Video4; OMV Feature 0 (Left-Top); FPS: 30 -> Corr: -0.235
#
# Video4; OMV Feature 1 (Right-Top); FPS: 1 -> Corr: -0.188
# Video4; OMV Feature 1 (Right-Top); FPS: 2 -> Corr: -0.243
# Video4; OMV Feature 1 (Right-Top); FPS: 3 -> Corr: -0.402
# Video4; OMV Feature 1 (Right-Top); FPS: 5 -> Corr: -0.384
# Video4; OMV Feature 1 (Right-Top); FPS: 6 -> Corr: -0.359
# Video4; OMV Feature 1 (Right-Top); FPS: 10 -> Corr: -0.3
# Video4; OMV Feature 1 (Right-Top); FPS: 15 -> Corr: -0.31
# Video4; OMV Feature 1 (Right-Top); FPS: 30 -> Corr: -0.284
#
# Video4; OMV Feature 2 (Left-Bottom); FPS: 1 -> Corr: -0.168
# Video4; OMV Feature 2 (Left-Bottom); FPS: 2 -> Corr: -0.208
# Video4; OMV Feature 2 (Left-Bottom); FPS: 3 -> Corr: -0.372
# Video4; OMV Feature 2 (Left-Bottom); FPS: 5 -> Corr: -0.349
# Video4; OMV Feature 2 (Left-Bottom); FPS: 6 -> Corr: -0.32
# Video4; OMV Feature 2 (Left-Bottom); FPS: 10 -> Corr: -0.267
# Video4; OMV Feature 2 (Left-Bottom); FPS: 15 -> Corr: -0.278
# Video4; OMV Feature 2 (Left-Bottom); FPS: 30 -> Corr: -0.249
#
# Video4; OMV Feature 3 (Right-Bottom); FPS: 1 -> Corr: -0.186
# Video4; OMV Feature 3 (Right-Bottom); FPS: 2 -> Corr: -0.243
# Video4; OMV Feature 3 (Right-Bottom); FPS: 3 -> Corr: -0.401
# Video4; OMV Feature 3 (Right-Bottom); FPS: 5 -> Corr: -0.393
# Video4; OMV Feature 3 (Right-Bottom); FPS: 6 -> Corr: -0.37
# Video4; OMV Feature 3 (Right-Bottom); FPS: 10 -> Corr: -0.312
# Video4; OMV Feature 3 (Right-Bottom); FPS: 15 -> Corr: -0.324
# Video4; OMV Feature 3 (Right-Bottom); FPS: 30 -> Corr: -0.298
#
# Video4; OMV Feature 4 (Object-Amount); FPS: 1 -> Corr: 0.1
# Video4; OMV Feature 4 (Object-Amount); FPS: 2 -> Corr: 0.048
# Video4; OMV Feature 4 (Object-Amount); FPS: 3 -> Corr: -0.044
# Video4; OMV Feature 4 (Object-Amount); FPS: 5 -> Corr: -0.257
# Video4; OMV Feature 4 (Object-Amount); FPS: 6 -> Corr: -0.336
# Video4; OMV Feature 4 (Object-Amount); FPS: 10 -> Corr: -0.438
# Video4; OMV Feature 4 (Object-Amount); FPS: 15 -> Corr: -0.448
# Video4; OMV Feature 4 (Object-Amount); FPS: 30 -> Corr: -0.454
#
# Video4; OMV Feature 5 (Confidence); FPS: 1 -> Corr: 0.443
# Video4; OMV Feature 5 (Confidence); FPS: 2 -> Corr: 0.491
# Video4; OMV Feature 5 (Confidence); FPS: 3 -> Corr: 0.411
# Video4; OMV Feature 5 (Confidence); FPS: 5 -> Corr: 0.54
# Video4; OMV Feature 5 (Confidence); FPS: 6 -> Corr: 0.581
# Video4; OMV Feature 5 (Confidence); FPS: 10 -> Corr: 0.609
# Video4; OMV Feature 5 (Confidence); FPS: 15 -> Corr: 0.607
# Video4; OMV Feature 5 (Confidence); FPS: 30 -> Corr: 0.597
#
# Video4; OMV Feature 6 (IOU); FPS: 1 -> Corr: 0.528
# Video4; OMV Feature 6 (IOU); FPS: 2 -> Corr: 0.414
# Video4; OMV Feature 6 (IOU); FPS: 3 -> Corr: 0.329
# Video4; OMV Feature 6 (IOU); FPS: 5 -> Corr: 0.333
# Video4; OMV Feature 6 (IOU); FPS: 6 -> Corr: 0.343
# Video4; OMV Feature 6 (IOU); FPS: 10 -> Corr: 0.28
# Video4; OMV Feature 6 (IOU); FPS: 15 -> Corr: 0.245
# Video4; OMV Feature 6 (IOU); FPS: 30 -> Corr: 0.217

# %%
# Corr Plot Format 2

for k in range(len(fpss)):
	fps = fpss[k]
	print(f"FPS: {fps}")

	for j in range(len(omv_videos[0][fpss[0]][0])):
		print(f"OMV Feature {j} ({omv_features[j]})")
		corr_list = []

		for i in range(len(plot_video_names)):
			video_name = plot_video_names[i]
		
			omv_fps = list(np.array(omv_videos[i][fps])[:, j])
			acc_fps = list(np.array(acc_videos[i])[:, k])

			# Remove Outliers
			outlier_index = [l for l in range(len(omv_fps)) if omv_fps[l] == -1]
			omv_fps_clean = filter_list_index(omv_fps, outlier_index)
			acc_fps_clean = filter_list_index(acc_fps, outlier_index)

			correlation_matrix = np.corrcoef(omv_fps_clean, acc_fps_clean)
			correlation_coefficient = correlation_matrix[0, 1]
			corr_list.append(correlation_coefficient)

		print(f'Average Corr Among All {len(plot_video_names)} Videos {round_float_to_sigfigs(np.average(np.array(corr_list)), 3)}')

		print("")
# Out:
# FPS: 1
# OMV Feature 0 (Left-Top)
# Average Corr Among All 4 Videos -0.062
#
# OMV Feature 1 (Right-Top)
# Average Corr Among All 4 Videos -0.067
#
# OMV Feature 2 (Left-Bottom)
# Average Corr Among All 4 Videos -0.064
#
# OMV Feature 3 (Right-Bottom)
# Average Corr Among All 4 Videos -0.067
#
# OMV Feature 4 (Object-Amount)
# Average Corr Among All 4 Videos 0.376
#
# OMV Feature 5 (Confidence)
# Average Corr Among All 4 Videos 0.151
#
# OMV Feature 6 (IOU)
# Average Corr Among All 4 Videos 0.453
#
# FPS: 2
# OMV Feature 0 (Left-Top)
# Average Corr Among All 4 Videos -0.023
#
# OMV Feature 1 (Right-Top)
# Average Corr Among All 4 Videos -0.026
#
# OMV Feature 2 (Left-Bottom)
# Average Corr Among All 4 Videos -0.031
#
# OMV Feature 3 (Right-Bottom)
# Average Corr Among All 4 Videos -0.03
#
# OMV Feature 4 (Object-Amount)
# Average Corr Among All 4 Videos 0.383
#
# OMV Feature 5 (Confidence)
# Average Corr Among All 4 Videos 0.186
#
# OMV Feature 6 (IOU)
# Average Corr Among All 4 Videos 0.398
#
# FPS: 3
# OMV Feature 0 (Left-Top)
# Average Corr Among All 4 Videos -0.056
#
# OMV Feature 1 (Right-Top)
# Average Corr Among All 4 Videos -0.05
#
# OMV Feature 2 (Left-Bottom)
# Average Corr Among All 4 Videos -0.061
#
# OMV Feature 3 (Right-Bottom)
# Average Corr Among All 4 Videos -0.052
#
# OMV Feature 4 (Object-Amount)
# Average Corr Among All 4 Videos 0.35
#
# OMV Feature 5 (Confidence)
# Average Corr Among All 4 Videos 0.245
#
# OMV Feature 6 (IOU)
# Average Corr Among All 4 Videos 0.29
#
# FPS: 5
# OMV Feature 0 (Left-Top)
# Average Corr Among All 4 Videos 0.041
#
# OMV Feature 1 (Right-Top)
# Average Corr Among All 4 Videos 0.054
#
# OMV Feature 2 (Left-Bottom)
# Average Corr Among All 4 Videos 0.04
#
# OMV Feature 3 (Right-Bottom)
# Average Corr Among All 4 Videos 0.054
#
# OMV Feature 4 (Object-Amount)
# Average Corr Among All 4 Videos 0.17
#
# OMV Feature 5 (Confidence)
# Average Corr Among All 4 Videos 0.334
#
# OMV Feature 6 (IOU)
# Average Corr Among All 4 Videos 0.328
#
# FPS: 6
# OMV Feature 0 (Left-Top)
# Average Corr Among All 4 Videos 0.076
#
# OMV Feature 1 (Right-Top)
# Average Corr Among All 4 Videos 0.101
#
# OMV Feature 2 (Left-Bottom)
# Average Corr Among All 4 Videos 0.073
#
# OMV Feature 3 (Right-Bottom)
# Average Corr Among All 4 Videos 0.097
#
# OMV Feature 4 (Object-Amount)
# Average Corr Among All 4 Videos 0.105
#
# OMV Feature 5 (Confidence)
# Average Corr Among All 4 Videos 0.385
#
# OMV Feature 6 (IOU)
# Average Corr Among All 4 Videos 0.34
#
# FPS: 10
# OMV Feature 0 (Left-Top)
# Average Corr Among All 4 Videos 0.082
#
# OMV Feature 1 (Right-Top)
# Average Corr Among All 4 Videos 0.104
#
# OMV Feature 2 (Left-Bottom)
# Average Corr Among All 4 Videos 0.083
#
# OMV Feature 3 (Right-Bottom)
# Average Corr Among All 4 Videos 0.105
#
# OMV Feature 4 (Object-Amount)
# Average Corr Among All 4 Videos -0.018
#
# OMV Feature 5 (Confidence)
# Average Corr Among All 4 Videos 0.437
#
# OMV Feature 6 (IOU)
# Average Corr Among All 4 Videos 0.24
#
# FPS: 15
# OMV Feature 0 (Left-Top)
# Average Corr Among All 4 Videos 0.059
#
# OMV Feature 1 (Right-Top)
# Average Corr Among All 4 Videos 0.08
#
# OMV Feature 2 (Left-Bottom)
# Average Corr Among All 4 Videos 0.06
#
# OMV Feature 3 (Right-Bottom)
# Average Corr Among All 4 Videos 0.08
#
# OMV Feature 4 (Object-Amount)
# Average Corr Among All 4 Videos -0.074
#
# OMV Feature 5 (Confidence)
# Average Corr Among All 4 Videos 0.459
#
# OMV Feature 6 (IOU)
# Average Corr Among All 4 Videos 0.18
#
# FPS: 30
# OMV Feature 0 (Left-Top)
# Average Corr Among All 4 Videos 0.067
#
# OMV Feature 1 (Right-Top)
# Average Corr Among All 4 Videos 0.079
#
# OMV Feature 2 (Left-Bottom)
# Average Corr Among All 4 Videos 0.07
#
# OMV Feature 3 (Right-Bottom)
# Average Corr Among All 4 Videos 0.082
#
# OMV Feature 4 (Object-Amount)
# Average Corr Among All 4 Videos -0.109
#
# OMV Feature 5 (Confidence)
# Average Corr Among All 4 Videos 0.483
#
# OMV Feature 6 (IOU)
# Average Corr Among All 4 Videos 0.133
