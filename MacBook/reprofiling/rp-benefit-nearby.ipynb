# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import sys

# %%
OMV_FEATURE_INDEX = [5, 6]
INITIAL_FPS = '15'
RESAMPLE_RATE = 2
TARGET_ACCURACY = 0.8
SAFEGUARD = 1

PERIOD = ['Day', "Afternoon", "Night"]
BASE_PERIOD_INDEX = 0
VIDEO_PREFIX = 'Scene-1-'
# RP_PERIOD = 100
RP_AMOUNT = 4
CLASS_INDEX = '2'
NUM_SIG = 6
NEARBY_WINDOW_SIZE = 12

# %%
# Plot
plot_directory = 'short_result/plot_set'
power_profile_directory = 'short_result/Dict-Per-Real-Second-Throughput-960.json'

# %%
colors = [
	'#e6194B',
	# '#f58231',
	'#9A6324',
	'#911eb4',
	'#3cb44b',
	'#f032e6',
	'#4363d8',
]

# %%
def load_json_file(file_path):
	try:
		with open(file_path, 'r') as file:
			data = json.load(file)
		return data
	
	except Exception as e:
		print(f"An error occurred while loading the JSON file: {e}")
		return None

# %%
def extract_fpss(metric_list):
	return list(metric_list[list(metric_list.keys())[0]][0]['metric'].keys())

# %%
def to_accuracy_vector(accuracy_result_seq, fpss, type='F1'):
	accuracy_vector = []
	for fps in fpss:
		accuracy_vector.append(accuracy_result_seq[fps][type])
	
	return accuracy_vector

# %%
def plot_scatter(xs, ys, x_label, y_label, title, fig_size=(8, 8)):
	plt.figure(figsize=fig_size)
	plt.scatter(xs, ys, c=colors[0], s=30, alpha=0.5)
	plt.title(title)
	plt.xlabel(x_label)
	plt.ylabel(y_label)
	plt.show()

# %%
def plot_scatter_label(xs, ys, labels, x_label, y_label, title, fig_size=(8, 8)):
	plt.figure(figsize=fig_size)
	for i in range(len(xs)):
		plt.scatter(xs[i], ys[i], c=colors[labels[i]], s=30, alpha=0.5)
	plt.title(title)
	plt.xlabel(x_label)
	plt.ylabel(y_label)
	plt.show()

# %%
def filter_list_index(input_list, indices_to_remove):
	return [item for i, item in enumerate(input_list) if i not in indices_to_remove]

# %%
def round_float_to_sigfigs(number, sigfigs):
	return round(number, sigfigs)

# %% [markdown]
# ## Plot

# %%
omv_features = ["Left-Top", "Right-Top", "Left-Bottom", "Right-Bottom", "Object-Amount", "Confidence", "IOU"]

# %%
plot_filenames = sorted(os.listdir(plot_directory))
plot_video_names = sorted(list(set([f.split('_')[0] for f in plot_filenames])))

# %%
fpss = extract_fpss(load_json_file(os.path.join(plot_directory, plot_video_names[0] + "_Accuracy_Result.json")))

# %%
omv_videos = []
acc_videos = []

for v in plot_video_names:
	omv_dict = {}
	for fps in fpss:
		omv_dict[fps] = []
	acc_list = []

	accuracy_result = load_json_file(os.path.join(plot_directory, v + "_Accuracy_Result.json"))
	movement_result = load_json_file(os.path.join(plot_directory, v + "_Movement_Result.json"))

	for class_idx in list(accuracy_result.keys()):
		for i in range(len(accuracy_result[class_idx])):
			accuracy_vector = to_accuracy_vector(accuracy_result[class_idx][i]['metric'], fpss)
			acc_list.append(accuracy_vector)

			for fps in fpss:
				movement_vector = movement_result[class_idx][i]['movement'][fps]
				omv_dict[fps].append(movement_vector)
	
	omv_videos.append(omv_dict)
	acc_videos.append(acc_list)

# %% [markdown]
# # Dataset

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import PolynomialFeatures

# %%
def transpose_array(arr):
	# Transpose the input array using zip and map it back to a list
	return [list(row) for row in zip(*arr)]

# %%
def my_train_test_split(x, y, test_size):
	split_point = int(len(x) * (1-test_size))
	return x[0:split_point], x[split_point:len(x)], y[0:split_point], y[split_point:len(x)]

# %%
def root_mean_squared_error(y_train, y_train_pred):
	return np.sqrt(mean_squared_error(y_train, y_train_pred))

# %%
# Dataset Build

dataset = {}

for i in range(len(plot_video_names)):
	video_name = plot_video_names[i]
	dataset[video_name] = {}
	
	for k in range(len(fpss)):
		fps = fpss[k]
		dataset[video_name][fps] = {}
		y_all = None
		x_all_t = []

		for j in range(len(omv_videos[0][fpss[0]][0])):	
			fps = fpss[k]

			omv_fps = list(np.array(omv_videos[i][fps])[:, j])
			acc_fps = list(np.array(acc_videos[i])[:, k])

			# Remove Outliers
			# outlier_index = [l for l in range(len(omv_fps)) if omv_fps[l] == -1]
			# omv_fps_clean = filter_list_index(omv_fps, outlier_index)
			# acc_fps_clean = filter_list_index(acc_fps, outlier_index)

			if j == 0:
				y_all = acc_fps.copy()
			if j in OMV_FEATURE_INDEX:
				x_all_t.append(omv_fps.copy())
		
		x_all = transpose_array(x_all_t)
		dataset[video_name][fps]['y_all'] = y_all
		dataset[video_name][fps]['x_all'] = x_all

# %%
def my_train_test_split(x, y, test_size):
	split_point = int(len(x) * (1-test_size))
	return x[0:split_point], x[split_point:len(x)], y[0:split_point], y[split_point:len(x)]

# %% [markdown]
# # Train and Test

# %%
def estimate_best_fps_v1(prediction_models, clip_omv_of_fps, fpss, target_accuracy, safeguard):
	accuracy_vector = [prediction_models[fps].predict([clip_omv_of_fps])[0] for fps in fpss]

	for i in range(len(fpss)):
		if accuracy_vector[i] >= target_accuracy:
			return fpss[min(i + safeguard, len(fpss)-1)]

	return fpss[-1]

# %%
def estimate_best_fps_v2(prediction_models, clip_omv_of_fps, fpss, target_accuracy, safeguard):
	accuracy_vector = [prediction_models[fps].predict([clip_omv_of_fps])[0] for fps in fpss]

	min_idx = 0
	for i in range(len(fpss)):
		if abs(accuracy_vector[i] - target_accuracy) < abs(accuracy_vector[min_idx] - target_accuracy):
			min_idx = i

	return fpss[min(min_idx + safeguard, len(fpss) - 1)]

# %%
def estimate_best_fps_v3(prediction_models, clip_omv_of_fps, fpss, target_accuracy, safeguard, last_fps):
	accuracy_vector = [prediction_models[fps].predict([clip_omv_of_fps])[0] for fps in fpss]

	min_idx = 0
	for i in range(len(fpss)):
		if abs(accuracy_vector[i] - target_accuracy) < abs(accuracy_vector[min_idx] - target_accuracy):
			min_idx = i
	
	corrected_min_idx = min_idx + safeguard
	if corrected_min_idx >= len(fpss) - 1:
		if last_fps == len(fpss) - 2:
			corrected_min_idx = len(fpss) - 1
		else:
			corrected_min_idx = len(fpss) - 2

	return fpss[corrected_min_idx]

# %%
def extract_metric_list(metric_list, fpss, feature='F1'):
	result_column = {}
	
	for fps in fpss: 
		result_column[fps] = [clip_metric['metric'][fps][feature] for clip_metric in metric_list]
	
	return result_column

# %%
def find_max_index(string_list):
	# Convert each element to integer
	int_list = [int(element) for element in string_list]
	
	# Find index of maximum integer value
	max_index, max_value = max(enumerate(int_list), key=lambda x: x[1])
	
	return max_value

def extract_cheapest_fps(accuracy_dict, fpss, threshold=0.75):
	max_fps = find_max_index(fpss)
	
	cheapest_fpss = []
	for i in range(len(accuracy_dict[fpss[0]])):
		curr_fps = max_fps
		for fps in fpss:
			if accuracy_dict[fps][i] >= threshold and int(fps) < int(curr_fps):
				curr_fps = fps
		
		cheapest_fpss.append(int(curr_fps))
	
	return cheapest_fpss

# %%
def extract_nearest_fps(accuracy_dict, fpss, threshold=0.75):
	nearest_fpss = []
	for i in range(len(accuracy_dict[fpss[0]])):
		curr_fps = fpss[0]
		for fps in fpss:
			if abs(accuracy_dict[fps][i] - threshold) < abs(accuracy_dict[curr_fps][i] - threshold):
				curr_fps = fps
		
		nearest_fpss.append(int(curr_fps))
	
	return nearest_fpss

# %%
def plot_mutiple_lines(xs, yss, x_label, y_label, y_legends, title, fig_size, label_size=28, font_size=32, legend_size=20):
	fig, ax1 = plt.subplots(figsize=fig_size)

	for i in range(len(yss)):
		ax1.plot(xs, yss[i], color=colors[i], label=y_legends[i])

	ax1.set_xlabel(x_label, fontsize=font_size)
	ax1.set_ylabel(y_label, fontsize=font_size)
	# ax1.set_title(title, fontsize=font_size)
	plt.xticks(fontsize=label_size)
	plt.yticks(fontsize=label_size)
	plt.legend(fontsize=legend_size)
	plt.grid(True)

	plt.show()

# %%
def plot_mutiple_lines_horizontal(xs, yss, x_axis, y_axis, y_label_prefix, y_labels, title, label_size=28, font_size=32, legend_size=16, line_width=3):
	fig, ax1 = plt.subplots(figsize=(9, 6))
	
	for i in range(len(yss)):
		ax1.plot(xs, yss[i], color=colors[i], marker='o', label=f'{y_label_prefix}{y_labels[i]}')

	ax1.set_xlabel(x_axis, fontsize=font_size)
	ax1.set_ylabel(y_axis, fontsize=font_size)
	ax1.set_title(title, fontsize=font_size)
	plt.xticks(fontsize=label_size)
	plt.yticks(fontsize=label_size)
	plt.legend(fontsize=legend_size)
	plt.grid(True)

	plt.show()

# %%
period_result = {}
period_result[VIDEO_PREFIX] = {}
period_result[VIDEO_PREFIX][TARGET_ACCURACY] = {}
period_result[VIDEO_PREFIX][TARGET_ACCURACY]['non_rp'] = {}

# %% [markdown]
# ## Non Re-profiling

# %%
def generate_train_index_sets(data_length, rp_period, rp_amount):
	train_sets = []
	curr_index = 0
	while curr_index < data_length:
		train_sets.append(list(range(curr_index, curr_index + rp_amount)))
		curr_index += rp_period
	
	return train_sets

# %%
nrp_baseline_accuracy_list = []
nrp_eva_accuracy_list = []
nrp_baseline_power_list = []
nrp_eva_power_list = []
for p in range(len(PERIOD)):
	print(f'Period: {PERIOD[p]}')
	period_video_name = f'{VIDEO_PREFIX}{PERIOD[p]}'

	# Test
	test_length = len(dataset[period_video_name]['30']['x_all'])
	train_index_list = generate_train_index_sets(test_length, sys.maxsize, RP_AMOUNT)

	accuracy_result = load_json_file(os.path.join(plot_directory, period_video_name + "_Accuracy_Result.json"))
	accuracy = extract_metric_list(accuracy_result[CLASS_INDEX], fpss)
	nearest_fps_list = extract_nearest_fps(accuracy, fpss, TARGET_ACCURACY)

	selected_fps_list_for_accuracy = []
	selected_fps_list_for_power = []
	last_fps = INITIAL_FPS
	train_index_list_idx = 0
	for i in range(test_length):
		if train_index_list_idx < len(train_index_list) and i == train_index_list[train_index_list_idx][0]:
			# Train
			prediction_models = {}
			for fps in fpss:
				prediction_models[fps] = LinearRegression()

			for fps in fpss:
				x_all = dataset[period_video_name][fps]['x_all']
				y_all = dataset[period_video_name][fps]['y_all']

				train_start_idx = train_index_list[train_index_list_idx][0]
				train_end_idx = train_index_list[train_index_list_idx][-1]

				x_train = x_all[train_start_idx : train_end_idx]
				y_train = y_all[train_start_idx : train_end_idx]
						
				prediction_models[fps].fit(x_train, y_train)

		if train_index_list_idx < len(train_index_list) and i in train_index_list[train_index_list_idx]:
			ground_truth_fps = str(nearest_fps_list[i])
			selected_fps_list_for_accuracy.append(ground_truth_fps)
			selected_fps_list_for_power.append(fpss[-1])
			last_fps = ground_truth_fps
			
			if i == train_index_list[train_index_list_idx][-1]:
				train_index_list_idx += 1
			
			continue

		if i % RESAMPLE_RATE != 0:
			selected_fps_list_for_accuracy.append(last_fps)
			selected_fps_list_for_power.append(last_fps)
			continue

		clip_omv_of_fps = dataset[period_video_name][last_fps]['x_all'][i]
		suggested_fps = estimate_best_fps_v3(prediction_models, clip_omv_of_fps, fpss, TARGET_ACCURACY, SAFEGUARD, last_fps)

		last_fps = suggested_fps
		selected_fps_list_for_accuracy.append(last_fps)
		selected_fps_list_for_power.append(last_fps)

	selected_fps_list_for_accuracy = [int(x) for x in selected_fps_list_for_accuracy]
	selected_fps_list_for_power = [int(x) for x in selected_fps_list_for_power]

	selected_accuracy_list = []
	for i in range(test_length):
		selected_throughput = str(selected_fps_list_for_accuracy[i])
		selected_accuracy = accuracy_result[CLASS_INDEX][i]['metric'][selected_throughput]['F1']
		selected_accuracy_list.append(selected_accuracy)
	
	nearest_accuracy_list = []
	for i in range(test_length):
		nearest_throughput = str(nearest_fps_list[i])
		nearest_accuracy = accuracy_result[CLASS_INDEX][i]['metric'][nearest_throughput]['F1']
		nearest_accuracy_list.append(nearest_accuracy)

	power_profile = load_json_file(os.path.join(power_profile_directory))
	max_power = power_profile[str(max([int(k) for k in list(power_profile.keys())]))]

	selected_power_list = []
	for st in selected_fps_list_for_power:
		if str(st) in power_profile:
			selected_power_list.append(power_profile[str(st)])
		else:
			selected_power_list.append(max_power)

	nearest_power_list = []
	for nt in nearest_fps_list:
		if str(nt) in power_profile:
			nearest_power_list.append(power_profile[str(nt)])
		else:
			nearest_power_list.append(max_power)
	
	time = range(test_length)
	print(f'Selected F1 Accuracy: {round(np.mean(np.array(selected_accuracy_list)), NUM_SIG)}')
	print(f'Nearest F1 Accuracy: {round(np.mean(np.array(nearest_accuracy_list)), NUM_SIG)}')
	print(f'Selected Power: {round(np.mean(np.array(selected_power_list)), NUM_SIG)}')
	print(f'Nearest Power: {round(np.mean(np.array(nearest_power_list)), NUM_SIG)}')

	nrp_eva_accuracy_list.append(selected_accuracy_list)
	nrp_baseline_accuracy_list.append(nearest_accuracy_list)
	nrp_eva_power_list.append(selected_power_list)
	nrp_baseline_power_list.append(nearest_power_list)

	# plot_mutiple_lines(time, [selected_fps_list_for_power, nearest_fps_list], 'Time', 'FPS', ['Selected', 'Optimal'], '', (24, 6))
	# plot_mutiple_lines(time, [selected_accuracy_list, nearest_accuracy_list], 'Time', 'Accuracy', ['Selected Accuracy', 'Nearest Accuracy'], '', (36, 6))
	# plot_mutiple_lines(time, [selected_power_list, nearest_power_list], 'Time', 'Power', ['Selected Power', 'Nearest Power'], '', (36, 6))

	print("")

period_result[VIDEO_PREFIX][TARGET_ACCURACY]['non_rp']['baseline_accuracy_list'] = nrp_baseline_accuracy_list
period_result[VIDEO_PREFIX][TARGET_ACCURACY]['non_rp']['eva_accuracy_list'] = nrp_eva_accuracy_list
period_result[VIDEO_PREFIX][TARGET_ACCURACY]['non_rp']['baseline_power_list'] = nrp_baseline_power_list
period_result[VIDEO_PREFIX][TARGET_ACCURACY]['non_rp']['eva_power_list'] = nrp_eva_power_list
# Out:
# Period: Day
# Selected F1 Accuracy: 0.900938
# Nearest F1 Accuracy: 0.817255
# Selected Power: 4.388927
# Nearest Power: 3.527889
#
# Period: Afternoon
# Selected F1 Accuracy: 0.817901
# Nearest F1 Accuracy: 0.833542
# Selected Power: 3.897361
# Nearest Power: 3.623025
#
# Period: Night
# Selected F1 Accuracy: 0.854134
# Nearest F1 Accuracy: 0.808664
# Selected Power: 4.852169
# Nearest Power: 3.976058

# %% [markdown]
# ## Re-profiling

# %%
rp_result = {}
rp_result[VIDEO_PREFIX] = {}
rp_result[VIDEO_PREFIX][TARGET_ACCURACY] = {}
rp_result[VIDEO_PREFIX][TARGET_ACCURACY]['rp'] = {}

rp_result[VIDEO_PREFIX][TARGET_ACCURACY]['rp']['eva_accuracy_list'] = []
rp_result[VIDEO_PREFIX][TARGET_ACCURACY]['rp']['eva_power_list'] = []

# %%
test_length = len(dataset[f'{VIDEO_PREFIX}{PERIOD[0]}']['30']['x_all'])

for start_idx in range(RP_AMOUNT, test_length-RP_AMOUNT-NEARBY_WINDOW_SIZE+1):
	train_index_list = [list(range(start_idx, start_idx+RP_AMOUNT))]
	print(f'Current Start Index: {start_idx}')
	
	# Old code
	rp_eva_accuracy = []
	rp_eva_power = []
	for p in range(len(PERIOD)):
		print(f'Period: {PERIOD[p]}')
		period_video_name = f'{VIDEO_PREFIX}{PERIOD[p]}'

		# Test
		test_length = len(dataset[period_video_name]['30']['x_all'])

		accuracy_result = load_json_file(os.path.join(plot_directory, period_video_name + "_Accuracy_Result.json"))
		accuracy = extract_metric_list(accuracy_result[CLASS_INDEX], fpss)
		nearest_fps_list = extract_nearest_fps(accuracy, fpss, TARGET_ACCURACY)

		selected_fps_list_for_accuracy = []
		selected_fps_list_for_power = []
		last_fps = INITIAL_FPS
		train_index_list_idx = 0
		for i in range(test_length):
			if train_index_list_idx < len(train_index_list) and i == train_index_list[train_index_list_idx][0]:
				# Train
				prediction_models = {}
				for fps in fpss:
					prediction_models[fps] = LinearRegression()

				for fps in fpss:
					x_all = dataset[period_video_name][fps]['x_all']
					y_all = dataset[period_video_name][fps]['y_all']

					train_start_idx = train_index_list[train_index_list_idx][0]
					train_end_idx = train_index_list[train_index_list_idx][-1]

					x_train = x_all[train_start_idx : train_end_idx]
					y_train = y_all[train_start_idx : train_end_idx]
							
					prediction_models[fps].fit(x_train, y_train)

			if train_index_list_idx < len(train_index_list) and i in train_index_list[train_index_list_idx]:
				ground_truth_fps = str(nearest_fps_list[i])
				selected_fps_list_for_accuracy.append(ground_truth_fps)
				selected_fps_list_for_power.append(fpss[-1])
				last_fps = ground_truth_fps
				
				if i == train_index_list[train_index_list_idx][-1]:
					train_index_list_idx += 1
				
				continue

			if i % RESAMPLE_RATE != 0:
				selected_fps_list_for_accuracy.append(last_fps)
				selected_fps_list_for_power.append(last_fps)
				continue

			clip_omv_of_fps = dataset[period_video_name][last_fps]['x_all'][i]
			suggested_fps = estimate_best_fps_v3(prediction_models, clip_omv_of_fps, fpss, TARGET_ACCURACY, SAFEGUARD, last_fps)

			last_fps = suggested_fps
			selected_fps_list_for_accuracy.append(last_fps)
			selected_fps_list_for_power.append(last_fps)

		selected_fps_list_for_accuracy = [int(x) for x in selected_fps_list_for_accuracy]
		selected_fps_list_for_power = [int(x) for x in selected_fps_list_for_power]

		selected_accuracy_list = []
		for i in range(test_length):
			selected_throughput = str(selected_fps_list_for_accuracy[i])
			selected_accuracy = accuracy_result[CLASS_INDEX][i]['metric'][selected_throughput]['F1']
			selected_accuracy_list.append(selected_accuracy)
		
		nearest_accuracy_list = []
		for i in range(test_length):
			nearest_throughput = str(nearest_fps_list[i])
			nearest_accuracy = accuracy_result[CLASS_INDEX][i]['metric'][nearest_throughput]['F1']
			nearest_accuracy_list.append(nearest_accuracy)

		power_profile = load_json_file(os.path.join(power_profile_directory))
		max_power = power_profile[str(max([int(k) for k in list(power_profile.keys())]))]

		selected_power_list = []
		for st in selected_fps_list_for_power:
			if str(st) in power_profile:
				selected_power_list.append(power_profile[str(st)])
			else:
				selected_power_list.append(max_power)

		nearest_power_list = []
		for nt in nearest_fps_list:
			if str(nt) in power_profile:
				nearest_power_list.append(power_profile[str(nt)])
			else:
				nearest_power_list.append(max_power)
		
		time = range(test_length)
		# print(f'Selected F1 Accuracy: {round(np.mean(np.array(selected_accuracy_list)), NUM_SIG)}')
		# print(f'Nearest F1 Accuracy: {round(np.mean(np.array(nearest_accuracy_list)), NUM_SIG)}')
		# print(f'Selected Power: {round(np.mean(np.array(selected_power_list)), NUM_SIG)}')
		# print(f'Nearest Power: {round(np.mean(np.array(nearest_power_list)), NUM_SIG)}')

		rp_eva_accuracy.append(round(np.mean(np.array(selected_accuracy_list[start_idx+RP_AMOUNT : start_idx+RP_AMOUNT+NEARBY_WINDOW_SIZE])), NUM_SIG))
		rp_eva_power.append(round(np.mean(np.array(selected_power_list[start_idx+RP_AMOUNT : start_idx+RP_AMOUNT+NEARBY_WINDOW_SIZE])), NUM_SIG))

		# plot_mutiple_lines(time, [selected_fps_list_for_power, nearest_fps_list], 'Time', 'FPS', ['Selected', 'Optimal'], '', (24, 6))
		# plot_mutiple_lines(time, [selected_accuracy_list, nearest_accuracy_list], 'Time', 'Accuracy', ['Selected Accuracy', 'Nearest Accuracy'], '', (36, 6))
		# plot_mutiple_lines(time, [selected_power_list, nearest_power_list], 'Time', 'Power', ['Selected Power', 'Nearest Power'], '', (36, 6))

		print("")

	rp_result[VIDEO_PREFIX][TARGET_ACCURACY]['rp']['eva_accuracy_list'].append(rp_eva_accuracy)
	rp_result[VIDEO_PREFIX][TARGET_ACCURACY]['rp']['eva_power_list'].append(rp_eva_power)
# Out:
# Current Start Index: 4
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 5
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 6
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 7
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 8
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 9
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 10
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 11
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 12
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 13
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 14
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 15
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 16
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 17
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 18
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 19
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 20
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 21
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 22
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 23
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 24
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 25
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 26
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 27
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 28
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 29
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 30
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 31
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 32
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 33
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 34
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 35
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 36
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 37
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 38
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 39
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 40
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 41
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 42
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 43
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 44
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 45
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 46
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 47
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 48
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 49
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 50
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 51
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 52
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 53
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 54
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 55
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 56
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 57
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 58
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 59
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 60
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 61
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 62
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 63
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 64
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 65
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 66
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 67
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 68
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 69
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 70
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 71
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 72
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 73
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 74
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 75
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 76
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 77
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 78
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 79
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 80
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 81
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 82
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 83
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 84
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 85
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 86
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 87
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 88
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 89
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 90
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 91
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 92
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 93
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 94
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 95
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 96
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 97
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 98
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 99
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 100
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 101
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 102
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 103
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 104
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 105
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 106
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 107
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 108
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 109
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 110
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 111
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 112
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 113
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 114
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 115
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 116
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 117
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 118
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 119
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 120
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 121
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 122
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 123
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 124
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 125
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 126
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 127
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 128
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 129
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 130
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 131
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 132
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 133
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 134
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 135
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 136
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 137
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 138
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 139
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 140
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 141
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 142
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 143
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 144
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 145
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 146
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 147
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 148
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 149
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 150
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 151
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 152
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 153
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 154
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 155
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 156
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 157
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 158
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 159
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 160
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 161
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 162
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 163
# Period: Day
#
# Period: Afternoon
#
# Period: Night
#
# Current Start Index: 164
# Period: Day
#
# Period: Afternoon
#
# Period: Night

# %%
def transpose_2d_list(matrix):
	"""
	Transpose a 2D list (matrix).

	Args:
			matrix (list of lists): The 2D list to transpose.

	Returns:
			list of lists: The transposed 2D list.
	"""
	# Use zip with unpacking to transpose the matrix
	return [list(row) for row in zip(*matrix)]

# %%
def plot_two_ys(xs, y1s, y2s, x_label, y1_label, y2_label, title, label_size=28, font_size=32):
	fig, ax1 = plt.subplots(figsize=(36, 9))

	ax1.plot(xs, y1s, color=colors[0], marker='o', label=y1_label)  # 'o' denotes the marker type
	ax1.set_xlabel(x_label, fontsize=font_size)
	ax1.set_ylabel(y1_label, color=colors[0], fontsize=font_size)
	ax1.tick_params(axis='both', labelsize=label_size)

	ax2 = ax1.twinx()
	ax2.plot(xs, y2s, color=colors[3], marker='o', label=y2_label)  # 'o' denotes the marker type
	ax2.set_ylabel(y2_label, color=colors[3], fontsize=font_size)
	ax2.tick_params(axis='y', labelsize=label_size)

	plt.title(title, fontsize=font_size)
	plt.grid(True)

	plt.show()

# %%
def plot_two_ys_horizontal_line(xs, y1s, y2s, x_label, y1_label, y2_label, title, horizontal_line=None, label_size=28, font_size=32):
	fig, ax1 = plt.subplots(figsize=(36, 9))

	ax1.plot(xs, y1s, color=colors[0], marker='o', label=y1_label, linewidth=2)  # 'o' denotes the marker type
	ax1.set_xlabel(x_label, fontsize=font_size)
	ax1.set_ylabel(y1_label, color=colors[0], fontsize=font_size)
	ax1.tick_params(axis='both', labelsize=label_size)
	ax1.set_xlim([0, 180])

	ax2 = ax1.twinx()
	ax2.plot(xs, y2s, color=colors[3], marker='o', label=y2_label, linewidth=2)  # 'o' denotes the marker type
	ax2.set_ylabel(y2_label, color=colors[3], fontsize=font_size)
	ax2.tick_params(axis='y', labelsize=label_size)
	ax2.set_xlim([0, 180])

	if horizontal_line is not None:
		ax1.axhline(y=horizontal_line, color=colors[4], linewidth=4)

	plt.title(title, fontsize=font_size)
	plt.grid(True)

	plt.show()

# %%
plot_non_rp_result = period_result[VIDEO_PREFIX][TARGET_ACCURACY]['non_rp']
plot_rp_result = rp_result[VIDEO_PREFIX][TARGET_ACCURACY]['rp']

# %%
eva_accuracy_list = plot_rp_result['eva_accuracy_list']
eva_power_list = plot_rp_result['eva_power_list']

for i in range(len(PERIOD)):
	p_accuracy_base_list = plot_non_rp_result['eva_accuracy_list'][i]
	p_power_base_list = plot_non_rp_result['eva_power_list'][i]

	p_accuracy_base_nearby_list = []
	p_power_base_nearby_list = []
	for start_idx in range(RP_AMOUNT, test_length-RP_AMOUNT-NEARBY_WINDOW_SIZE+1):
		p_accuracy_base_nearby_list.append(round(np.mean(np.array(p_accuracy_base_list[start_idx+RP_AMOUNT : start_idx+RP_AMOUNT+NEARBY_WINDOW_SIZE])), NUM_SIG))
		p_power_base_nearby_list.append(round(np.mean(np.array(p_power_base_list[start_idx+RP_AMOUNT : start_idx+RP_AMOUNT+NEARBY_WINDOW_SIZE])), NUM_SIG))

	p_accuracy_list = [l[i] for l in eva_accuracy_list]
	assert(len(p_accuracy_list) == len(p_accuracy_base_nearby_list))
	p_accuracy_change = [(abs(p_accuracy_base_nearby_list[j] - TARGET_ACCURACY) - abs(p_accuracy_list[j] - TARGET_ACCURACY)) for j in range(len(p_accuracy_list))]

	p_power_list = [l[i] for l in eva_power_list]
	assert(len(p_power_list) == len(p_power_base_nearby_list))
	p_power_change = [(p_power_list[j] / p_power_base_nearby_list[j]) for j in range(len(p_power_list))]

	time = list(range(RP_AMOUNT, test_length-RP_AMOUNT-NEARBY_WINDOW_SIZE+1))
	plot_two_ys_horizontal_line(time, list(np.array(p_accuracy_change) * 100), list(np.array(p_power_change) * 100 - 100), 'Time', 'Accuracy Gain (%)', 'Power Increase (%)', f'W/S = {RP_AMOUNT}, Nearby = {NEARBY_WINDOW_SIZE}', 0)
