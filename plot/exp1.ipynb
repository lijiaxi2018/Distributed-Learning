# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
LABEL_SIZE = 28
FONTSIZE = 32

# Your data
latency = [512, 396, 321, 271, 223, 198, 178, 170]
frequency = [0.65, 0.88, 1.11, 1.34, 1.57, 1.80, 2.04, 2.20]
energy_consumption = [865, 756, 702, 681, 715, 737, 808, 898]

# Start plotting
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot latency in orange with straight lines on the primary y-axis
ax1.plot(frequency, latency, color='orange', marker='o', label='Latency')  # 'o' denotes the marker type
ax1.set_xlabel('CPU Frequency (GHz)', fontsize=FONTSIZE)
ax1.set_ylabel('Latency (s)', color='orange', fontsize=FONTSIZE)
ax1.tick_params(axis='both', labelsize=LABEL_SIZE)

latency_ticks = np.arange(0, max(latency) + 1, 100)  # Adjust step size as needed
ax1.set_yticks(latency_ticks)

# Create a second y-axis for energy consumption
ax2 = ax1.twinx()
ax2.plot(frequency, energy_consumption, color='blue', marker='o', label='Energy Consumption')  # 'o' denotes the marker type
ax2.set_ylabel('Energy Consumption (J)', color='blue', fontsize=FONTSIZE)
ax2.tick_params(axis='y', labelsize=LABEL_SIZE)

energy_ticks = np.arange(500, max(energy_consumption) + 1, 100)  # Adjust step size as needed
ax2.set_yticks(energy_ticks)

# plt.savefig('pre_exp_dvfs.png', dpi=300)

# Display the plot
plt.show()

# %%
LABEL_SIZE = 28
FONTSIZE = 32

# Your data
latency = [249, 173, 170, 169]
frequency = [0, 50, 60, 70]
energy_consumption = [1342, 942, 898, 902]

# Start plotting
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot latency in orange with straight lines on the primary y-axis
ax1.plot(frequency, latency, color='orange', marker='o', label='Latency')  # 'o' denotes the marker type
ax1.set_xlabel('Pruning Degree (%)', fontsize=FONTSIZE)
ax1.set_ylabel('Latency (s)', color='orange', fontsize=FONTSIZE)
ax1.tick_params(axis='both', labelsize=LABEL_SIZE)

# Create a second y-axis for energy consumption
ax2 = ax1.twinx()
ax2.plot(frequency, energy_consumption, color='blue', marker='o', label='Energy Consumption')  # 'o' denotes the marker type
ax2.set_ylabel('Energy Consumption (J)', color='blue', fontsize=FONTSIZE)
ax2.tick_params(axis='y', labelsize=LABEL_SIZE)

# plt.savefig('pre_exp_pruning.png', dpi=300)

# Display the plot
plt.show()

# %%
# import matplotlib.pyplot as plt

# # Your data
# latency = [249, 173, 170, 169]
# frequency = [0, 50, 60, 70]
# energy_consumption = [1342, 942, 898, 902]
# accuracy = [36.5, 36.9, 36.5, 34.1]  # Extended to match the length of other lists

# # Start plotting with specified plot size
# fig, ax1 = plt.subplots(figsize=(10, 6))  # Width, Height in inches

# # Plot latency in orange with straight lines on the primary y-axis
# ax1.plot(frequency, latency, 'o-', color='orange', label='Latency')  # 'o-' denotes the marker type and line style
# ax1.set_xlabel('CPU Frequency (GHz)', fontsize=14)
# ax1.set_ylabel('Latency & Accuracy', fontsize=14)  # Adjusted label
# ax1.tick_params(axis='both', labelsize=12)  # Set the size of the axis tick labels

# # Plot accuracy in green with straight lines on the primary y-axis
# accuracy_line, = ax1.plot(frequency, accuracy, 's-', color='green', label='Accuracy')  # 's-' denotes the square marker type and line style
# for i, txt in enumerate(accuracy):
#     ax1.annotate(txt, (frequency[i], accuracy[i]), textcoords="offset points", xytext=(0,10), ha='center', fontsize=9)

# ax1.legend(loc='upper right')  # Display legend in the upper right corner

# # Create a second y-axis for energy consumption
# ax2 = ax1.twinx()
# ax2.plot(frequency, energy_consumption, 'o-', color='blue', label='Energy Consumption')  # 'o-' denotes the marker type and line style
# ax2.set_ylabel('Energy Consumption', fontsize=14)
# ax2.tick_params(axis='y', labelsize=12)  # Set the size of the y-axis tick labels for the second axis

# # Display the plot
# plt.show()
